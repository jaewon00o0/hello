# %% [markdown]
# <a href="https://colab.research.google.com/github/jaewon00o0/kbu-2.1/blob/main/2026_03_27%EC%88%98%EC%97%85%EB%82%B4%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
4.네이버와_구글의_서버_헤더_정보_비교하기

# %%
import requests

# %%
res_naver = requests.get("https://www.naver.com")
res_google = requests.get("https://www.google.com")

# %%
print(f"Server: {res_naver.headers.get('Server')}")
print(f"Date: {res_naver.headers.get('Date')}")
# Out:
# Server: nfront
# Date: Fri, 27 Mar 2026 04:01:54 GMT

# %%
print(f"Server: {res_google.headers.get('Server')}")
print(f"Date: {res_google.headers.get('Date')}")
# Out:
# Server: gws
# Date: Fri, 27 Mar 2026 04:01:54 GMT

# %%
print("\n[네이버 전체 헤더]\n", res_naver.headers)
print("\n[구글 전체 헤더]\n", res_google.headers)
# Out:
# [네이버 전체 헤더]
#  {'Content-Type': 'text/html; charset=UTF-8', 'Cache-Control': 'no-cache, no-store, must-revalidate', 'Pragma': 'no-cache', 'x-frame-options': 'DENY', 'x-xss-protection': '1; mode=block', 'strict-transport-security': 'max-age=63072000; includeSubdomains', 'referrer-policy': 'unsafe-url', 'Content-Encoding': 'gzip', 'Server': 'nfront', 'Date': 'Fri, 27 Mar 2026 04:01:54 GMT', 'Content-Length': '46492', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding'}
#
# [구글 전체 헤더]
#  {'Date': 'Fri, 27 Mar 2026 04:01:54 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Content-Type': 'text/html; charset=ISO-8859-1', 'Content-Security-Policy-Report-Only': "object-src 'none';base-uri 'self';script-src 'nonce-EQ1Ly7gJzppSy1N0xC8FGQ' 'strict-dynamic' 'report-sample' 'unsafe-eval' 'unsafe-inline' https: http:;report-uri https://csp.withgoogle.com/csp/gws/other-hp", 'Reporting-Endpoints': 'default="//www.google.com/httpservice/retry/jserror?ei=MgHGacWgO-bj1e8P1b7HiQk&cad=crash&error=Page%20Crash&jsel=1&bver=2410&dpf=6T-WW1hu2KuHvN4scUZqVdAfdbc8L2xTZ80EuWtKHYg"', 'Accept-CH': 'Sec-CH-Prefers-Color-Scheme', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': '__Secure-STRP=AEEP7gIee8xR2NUOFFjmi6-vbDhgErkOCvFaaTIYMRbV7jgUjLxVEmmGTG-MkxQ5ozEeo80ayH6RBwZvOwVJdouMc_FxObyFVg; expires=Fri, 27-Mar-2026 04:06:55 GMT; path=/; domain=.google.com; Secure; SameSite=strict, AEC=AaJma5uP36RsoSNikWgdM_aipHLBXUv2NGul6nOUd7lJz5MgUrgkcEB4EqY; expires=Wed, 23-Sep-2026 04:01:55 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax, NID=530=OzVtGm_kLpg5aVC7aCFbnNgYCQpWqNkflDqENzdxj5yVLCga1dKz_vgSjCXSScGofvO5bdhZtW5H887sG6exWNyfr-28B5EBIusB9PdGTd3jPZMYrr72ZfPj5M3h_vwoVtlbjjgPt4DQLQe8fzOlKslLhnw1w9x0lOL5uQHM04G2jubVQbsqdhxoGJyQQHxLx04w7E7zatR9Iv59O-MAehOvsYK6n6jegMc; expires=Sat, 26-Sep-2026 04:01:54 GMT; path=/; domain=.google.com; HttpOnly, __Secure-BUCKET=CNUE; expires=Wed, 23-Sep-2026 04:01:54 GMT; path=/; domain=.google.com; Secure; HttpOnly', 'Transfer-Encoding': 'chunked'}

# %%
5. url = "https://jsonplaceholder.typicode.com/users" 에서 requests 모듈로 json파일로
불러와 데이터프레임으로 저장하고 컬럼명(변수명)이 “address”인 series의 내용을
데이터프레임으로 변경하라
# Out:
#   File "/tmp/ipykernel_1271/607277357.py", line 2
#     불러와 데이터프레임으로 저장하고 컬럼명(변수명)이 “address”인 series의 내용을
#                                 ^
# SyntaxError: invalid character '“' (U+201C)

# %%
import requests
import pandas as pd
from IPython.display import display

# %%
url = "https://jsonplaceholder.typicode.com/users"

# %%
response = requests.get(url)
data = response.json()

# %%
df = pd.DataFrame(data)

# %%
address_df = pd.json_normalize(df['address'])

# %%
display(df)
display(address_df)
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
# 5  {'street': 'Norberto Crossing', 'suite': 'Apt....   1-477-935-8478 x6430
# 6  {'street': 'Rex Trail', 'suite': 'Suite 280', ...           210.067.6132
# 7  {'street': 'Ellsworth Summit', 'suite': 'Suite...      586.493.6943 x140
# 8  {'street': 'Dayna Park', 'suite': 'Suite 449',...   (775)976-6794 x41206
# 9  {'street': 'Kattie Turnpike', 'suite': 'Suite ...           024-648-3804
#
#          website                                            company
# 0  hildegard.org  {'name': 'Romaguera-Crona', 'catchPhrase': 'Mu...
# 1  anastasia.net  {'name': 'Deckow-Crist', 'catchPhrase': 'Proac...
# 2    ramiro.info  {'name': 'Romaguera-Jacobson', 'catchPhrase': ...
# 3       kale.biz  {'name': 'Robel-Corkery', 'catchPhrase': 'Mult...
# 4   demarco.info  {'name': 'Keebler LLC', 'catchPhrase': 'User-c...
# 5        ola.org  {'name': 'Considine-Lockman', 'catchPhrase': '...
# 6       elvis.io  {'name': 'Johns Group', 'catchPhrase': 'Config...
# 7   jacynthe.com  {'name': 'Abernathy Group', 'catchPhrase': 'Im...
# 8     conrad.com  {'name': 'Yost and Sons', 'catchPhrase': 'Swit...
# 9    ambrose.net  {'name': 'Hoeger LLC', 'catchPhrase': 'Central...
#               street      suite            city     zipcode   geo.lat  \
# 0        Kulas Light   Apt. 556     Gwenborough  92998-3874  -37.3159
# 1      Victor Plains  Suite 879     Wisokyburgh  90566-7771  -43.9509
# 2  Douglas Extension  Suite 847   McKenziehaven  59590-4157  -68.6102
# 3        Hoeger Mall   Apt. 692     South Elvis  53919-4257   29.4572
# 4       Skiles Walks  Suite 351      Roscoeview       33263  -31.8129
# 5  Norberto Crossing   Apt. 950   South Christy  23505-1337  -71.4197
# 6          Rex Trail  Suite 280       Howemouth  58804-1099   24.8918
# 7   Ellsworth Summit  Suite 729       Aliyaview       45169  -14.3990
# 8         Dayna Park  Suite 449  Bartholomebury  76495-3109   24.6463
# 9    Kattie Turnpike  Suite 198     Lebsackbury  31428-2261  -38.2386
#
#      geo.lng
# 0    81.1496
# 1   -34.4618
# 2   -47.0653
# 3  -164.2990
# 4    62.5342
# 5    71.7478
# 6    21.8984
# 7  -120.7677
# 8  -168.8889
# 9    57.2232

# %%
6. url = "https://jsonplaceholder.typicode.com/posts" 에서 데이터를 불러와 index가
짝수인 내용만 엑셀로 저장하여 다운로드 받아라
# Out:
#   File "/tmp/ipykernel_1271/614665103.py", line 1
#     6. url = "https://jsonplaceholder.typicode.com/posts" 에서 데이터를 불러와 index가
#        ^
# SyntaxError: invalid syntax

# %%
import requests
import pandas as pd

# %%
response = requests.get(url)
data = response.json()

# %%
df = pd.DataFrame(data)

# %%
even_df = df[df.index % 2 == 0]

# %%
file_name = "even_posts.xlsx"
even_df.to_excel(file_name, index=False)

# %%
from google.colab import files
files.download(file_name)

# %%
7.url = "https://jsonplaceholder.typicode.com/posts"에서 데이터를 불러와
requests.get(url, params=params)를 사용하여 사용자가 Gradio UI를 통해 userId를
입력하면 실시간으로 해당 데이터를 필터링하여 Pandas 데이터프레임으로 보여주는
코드를 작성하라

# %%
import requests
import pandas as pd
import gradio as gr

# %%
def get_user_posts(user_id):
    if not user_id or user_id <= 0:
        return pd.DataFrame()
    url = "https://jsonplaceholder.typicode.com/posts"
    params = {'userId': int(user_id)}
    data = requests.get(url, params=params).json()
    return pd.DataFrame(data)

# %%
# url = "https://jsonplaceholder.typicode.com/posts"

# %%
# params = {'userId': int(user_id)}

# %%
# data = requests.get(url, params=params).json()
#     return pd.DataFrame(data)

# %%
ui = gr.Interface(
    fn=fetch_and_translate,
    inputs=gr.Number(label="userId를 입력하세요 (예: 1, 2)", precision=0),
    outputs=[
        gr.Dataframe(label="검색된 포스트 목록"),
        gr.Textbox(label="원본 텍스트"),
        gr.Textbox(label="번역된 텍스트")
    ],
    title="실시간 포스트 검색기 및 번역기",
    live=True
)

# %%
ui.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://164900d2f5d082a2c9.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://164900d2f5d082a2c9.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
9. Gemini API Key 발급 및 코딩하기(Agent AI)
a. 7번과제를 번역하여 제공해주는 UI를 만들어라

# %%
# !pip install gradio pandas requests
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (5.50.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.12.1)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.135.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.7.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio) (26.0)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<=2.12.3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.12.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.22)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.15.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.24.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.42.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.4.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (2.41.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
import requests
import pandas as pd
import gradio as gr
from google.colab import ai

# %%
def fetch_and_translate(user_id):
    # --- [7번 과제 로직] API에서 데이터 실시간 호출 ---
    url = "https://jsonplaceholder.typicode.com/posts"

    # user_id가 빈 값(None)이 아니면 파라미터 적용
    params = {'userId': int(user_id)} if user_id else {}
    translated_text = "번역할 내용이 없습니다."  # Default value
    original_text_display = ""

    try:
        response = requests.get(url, params=params)
        data = response.json()
        df = pd.DataFrame(data)
    except Exception as e:
        return pd.DataFrame(), f"데이터 호출 에러: {e}", translated_text

    if df.empty:
        return df, "해당 userId의 데이터가 없습니다.", translated_text

    # --- [9번 과제 로직] 첫 번째 포스트 내용 번역 ---
    first_row = df.iloc[0]
    original_text_display = f"Title: {first_row['title']}\nBody: {first_row['body']}"

    # Gemini API를 사용하여 번역 (추후 구현)
    prompt = f"다음 영어 문장을 한국어로 자연스럽게 번역해줘:\n{original_text_display}"
    try:
        # API 키 없이 코랩 내장 AI로 텍스트 생성
        ai_response = ai.generate_text(prompt)
        # 응답 객체에서 텍스트 추출
        translated_text = ai_response.text if hasattr(ai_response, 'text') else str(ai_response)
    except Exception as e:
        translated_text = f"번역 중 오류가 발생했습니다.\n(코랩 환경인지 확인해주세요): {e}"

    return df, original_text_display, translated_text

# %%
with gr.Blocks(theme=gr.themes.Soft()) as app:
    gr.Markdown("##  게시글 실시간 필터링 및 1행 AI 번역기")
    gr.Markdown("7번 과제(userId 필터링)와 9번 과제(첫 행 번역)를 통합한 화면입니다.")
# Out:
# /tmp/ipykernel_1271/4294966568.py:1: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft()) as app:

# %%
    with gr.Row():
        user_id_input = gr.Number(label="User ID 입력 (실시간 필터링)", value=1, precision=0)

    with gr.Row():
        df_output = gr.Dataframe(label="필터링된 데이터프레임 (7번 과제 결과)", interactive=False)

    gr.Markdown("### 🤖 첫 번째 행(1행) 번역 결과 (9번 과제 - Colab AI)")
    with gr.Row():
        original_output = gr.Textbox(label="원본 텍스트 (1행)", lines=5, interactive=False)
        translated_output = gr.Textbox(label="🇰🇷 한국어 번역", lines=5, interactive=False)

    # user_id_input이 변경될 때마다 fetch_and_translate 함수 호출
    user_id_input.change(
        fn=fetch_and_translate,
        inputs=user_id_input,
        outputs=[df_output, original_output, translated_output],
        # api_name='fetch_and_translate' # API 이름 설정 (선택 사항)
    )

# %%
app.launch(debug=True)
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://7eef669bb84764ba2c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7eef669bb84764ba2c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
