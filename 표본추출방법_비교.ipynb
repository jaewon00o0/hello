# %% [markdown]
# <a href="https://colab.research.google.com/github/jaewon00o0/hello/blob/main/%ED%91%9C%EB%B3%B8%EC%B6%94%EC%B6%9C%EB%B0%A9%EB%B2%95_%EB%B9%84%EA%B5%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#분포는 데이터가 왼쪽에 밀집이 되어있고 오른쪽으로 갈수록 점이 뜨문뜨문하게 있는데
#팁을 많이 주는 손님이 소수 존재한다는 의미입니다

# %%
#평균은 전체데이터의 합을 나누면 평균 2.99$입니다

# %%
#분산은 데이터가 평균으로부터 얼마나 퍼져있는지 알려주는데 변동성이 1.91정도입니다

# %%
#평균의 함정(the pitfall of mean)
#예를들어 9명이 1$로 팁을 내고 1명이 100$를내면 평균팁이 10.9$가됩니다
#하지만 이 집단에서 $10.9 근처의 팁을 낸 사람은 아무도 없습니다.

# %%
#결론: tip 데이터처럼 비대칭이 심한 분포에서는 평균이 데이터의 대표성을 왜곡할 수 있습니다.
#이럴 때는 중앙값을 함께 보는 것이 훨씬 정확합니다.

# %%
#앞서 살펴본 3가지 방법(단순 무작위,층화,계통)을 tips 모집단에 적용했을 때의 비교입니다.

# %%
#단순무작위의 특징은 운에 맡기는 것입니다 데이터가 많을 떈 무난하지만 우연하게 이상치가
#많아지면 오차가 커집니다

# %%
#층화 추출 그룹별로 비율에 맞춰 추출합니다 요일,식사시에따라 팁차이가 크므로 비율을 고르게
#반영해야 모집단을 잘나타냅니다

# %%
#계통추출은 일정한 간격으로 추출합니다 데이터가 특정 순서로 정렬되어 있다면 효과적이겠지만
#특정 패턴이 반복되는 경우 데이터가 왜곡될 위험이 있습니다

# %%
#층화추출이 가장 적합합니다.
#이유는 tips 데이터셋이 요일,시간대,성별등 결과에 영향을 미칠 수 있는 명확한
#범주형 변수들을 가지고 있기 때문입니다. 단순히 무작위로
#뽑는 것보다금요일 저녁 손님,일요일 점심 손님의 비중을 모집단과 똑같이 맞춰서 뽑는
#것이 평균과 분산의 오차를 줄이는 데 가장 유리합니다.
