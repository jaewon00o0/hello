# %% [markdown]
# <a href="https://colab.research.google.com/github/jaewon00o0/kbu-2.1/blob/main/index%EA%B0%80%20%EC%A7%9D%EC%88%98%EC%9D%B8%20%EB%82%B4%EC%9A%A9%EB%A7%8C%20%EC%97%91%EC%85%80%EB%A1%9C%20%EC%A0%80%EC%9E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
url = "https://jsonplaceholder.typicode.com/posts"

# %%
response = requests.get(url)
data = response.json()

# %%
df = pd.DataFrame(data)

# %%
even_df = df[df.index % 2 == 0]

# %%
file_name = "even_posts.xlsx"
even_df.to_excel(file_name, index=False)

# %%
from google.colab import files
files.download(file_name)
